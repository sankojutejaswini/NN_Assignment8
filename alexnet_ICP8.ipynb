# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import RMSprop, Adam
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
(x_train, y_train), (x_test, y_test)  = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
y_train = y_train.reshape(-1,)

# %%
# Reshape converting 2D to 1D
y_test = y_test.reshape(-1,)
y_train = y_train.reshape(-1,)

# %%
# This code normalazation
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2
)

# Define Alexnet Model
AlexNet = Sequential()

AlexNet.add(Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='same', input_shape=(32,32,3), activation='relu'))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

AlexNet.add(Conv2D(filters=64, kernel_size=(5,5), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

AlexNet.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())

AlexNet.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())

AlexNet.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
AlexNet.add(BatchNormalization())
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

AlexNet.add(Flatten())
AlexNet.add(Dense(512, activation='relu'))
AlexNet.add(Dropout(0.5))

AlexNet.add(Dense(256, activation='relu'))
AlexNet.add(Dropout(0.5))

AlexNet.add(Dense(10, activation='softmax'))

# Define optimizer
opt = Adam(learning_rate=0.001)

# Compile model with 'sparse_categorical_crossentropy'
AlexNet.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print model summary
AlexNet.summary()

# Train model
history = AlexNet.fit(datagen.flow(x_train, y_train, batch_size=64),
                      epochs=50,
                      validation_data=(x_test, y_test),
                      verbose=1)

# Access validation loss and accuracy
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        51264
#
#  batch_normalization_1 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_2 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_3 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          73792
#
#  batch_normalization_4 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 1,007,754
# Trainable params: 1,006,922
# Non-trainable params: 832
# _________________________________________________________________
# Epoch 1/50
# 782/782 [==============================] - 45s 40ms/step - loss: 1.8114 - accuracy: 0.3514 - val_loss: 1.7645 - val_accuracy: 0.3792
# Epoch 2/50
# 782/782 [==============================] - 30s 38ms/step - loss: 1.4190 - accuracy: 0.4968 - val_loss: 1.2400 - val_accuracy: 0.5575
# Epoch 3/50
# 782/782 [==============================] - 31s 40ms/step - loss: 1.2436 - accuracy: 0.5646 - val_loss: 1.1429 - val_accuracy: 0.6014
# Epoch 4/50
# 782/782 [==============================] - 29s 38ms/step - loss: 1.1386 - accuracy: 0.6099 - val_loss: 1.0476 - val_accuracy: 0.6395
# Epoch 5/50
# 782/782 [==============================] - 30s 39ms/step - loss: 1.0538 - accuracy: 0.6403 - val_loss: 1.2559 - val_accuracy: 0.5751
# Epoch 6/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.9760 - accuracy: 0.6695 - val_loss: 0.8589 - val_accuracy: 0.7081
# Epoch 7/50
# 782/782 [==============================] - 29s 38ms/step - loss: 0.9233 - accuracy: 0.6899 - val_loss: 0.9162 - val_accuracy: 0.6766
# Epoch 8/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.8745 - accuracy: 0.7066 - val_loss: 0.8274 - val_accuracy: 0.7203
# Epoch 9/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.8398 - accuracy: 0.7204 - val_loss: 0.8321 - val_accuracy: 0.7253
# Epoch 10/50
# 782/782 [==============================] - 31s 39ms/step - loss: 0.8012 - accuracy: 0.7325 - val_loss: 0.7152 - val_accuracy: 0.7612
# Epoch 11/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.7619 - accuracy: 0.7481 - val_loss: 0.6680 - val_accuracy: 0.7746
# Epoch 12/50
# 782/782 [==============================] - 31s 39ms/step - loss: 0.7424 - accuracy: 0.7524 - val_loss: 0.7769 - val_accuracy: 0.7352
# Epoch 13/50
# 782/782 [==============================] - 30s 39ms/step - loss: 0.7144 - accuracy: 0.7638 - val_loss: 0.6993 - val_accuracy: 0.7653
# Epoch 14/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.6881 - accuracy: 0.7721 - val_loss: 0.8087 - val_accuracy: 0.7478
# Epoch 15/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.6664 - accuracy: 0.7797 - val_loss: 0.7009 - val_accuracy: 0.7678
# Epoch 16/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6447 - accuracy: 0.7850 - val_loss: 0.6022 - val_accuracy: 0.8024
# Epoch 17/50
# 782/782 [==============================] - 29s 38ms/step - loss: 0.6284 - accuracy: 0.7904 - val_loss: 0.7988 - val_accuracy: 0.7348
# Epoch 18/50
# 782/782 [==============================] - 30s 39ms/step - loss: 0.6150 - accuracy: 0.7963 - val_loss: 0.5948 - val_accuracy: 0.7960
# Epoch 19/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.5890 - accuracy: 0.8037 - val_loss: 0.6111 - val_accuracy: 0.7982
# Epoch 20/50
# 782/782 [==============================] - 30s 39ms/step - loss: 0.5761 - accuracy: 0.8070 - val_loss: 0.6178 - val_accuracy: 0.7953
# Epoch 21/50
# 782/782 [==============================] - 30s 39ms/step - loss: 0.5659 - accuracy: 0.8119 - val_loss: 0.5914 - val_accuracy: 0.8039
# Epoch 22/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.5523 - accuracy: 0.8174 - val_loss: 0.6304 - val_accuracy: 0.7980
# Epoch 23/50
# 782/782 [==============================] - 30s 39ms/step - loss: 0.5421 - accuracy: 0.8199 - val_loss: 0.6601 - val_accuracy: 0.7879
# Epoch 24/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.5301 - accuracy: 0.8226 - val_loss: 0.6260 - val_accuracy: 0.8047
# Epoch 25/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.5171 - accuracy: 0.8264 - val_loss: 0.7595 - val_accuracy: 0.7593
# Epoch 26/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.5136 - accuracy: 0.8272 - val_loss: 0.5132 - val_accuracy: 0.8303
# Epoch 27/50
# 782/782 [==============================] - 30s 39ms/step - loss: 0.5025 - accuracy: 0.8323 - val_loss: 0.6904 - val_accuracy: 0.7858
# Epoch 28/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.4995 - accuracy: 0.8329 - val_loss: 0.6182 - val_accuracy: 0.7920
# Epoch 29/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.4871 - accuracy: 0.8381 - val_loss: 0.6132 - val_accuracy: 0.8036
# Epoch 30/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.4869 - accuracy: 0.8396 - val_loss: 0.4917 - val_accuracy: 0.8371
# Epoch 31/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.4773 - accuracy: 0.8422 - val_loss: 0.5117 - val_accuracy: 0.8322
# Epoch 32/50
# 782/782 [==============================] - 30s 39ms/step - loss: 0.4687 - accuracy: 0.8422 - val_loss: 0.4655 - val_accuracy: 0.8468
# Epoch 33/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4610 - accuracy: 0.8454 - val_loss: 0.4717 - val_accuracy: 0.8463
# Epoch 34/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4547 - accuracy: 0.8479 - val_loss: 0.4931 - val_accuracy: 0.8400
# Epoch 35/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.4482 - accuracy: 0.8480 - val_loss: 0.5273 - val_accuracy: 0.8288
# Epoch 36/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4475 - accuracy: 0.8488 - val_loss: 0.5719 - val_accuracy: 0.8172
# Epoch 37/50
# 782/782 [==============================] - 30s 38ms/step - loss: 0.4340 - accuracy: 0.8545 - val_loss: 0.5298 - val_accuracy: 0.8311
# Epoch 38/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4384 - accuracy: 0.8538 - val_loss: 0.5276 - val_accuracy: 0.8288
# Epoch 39/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4309 - accuracy: 0.8557 - val_loss: 0.5766 - val_accuracy: 0.8263
# Epoch 40/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.4237 - accuracy: 0.8582 - val_loss: 0.4909 - val_accuracy: 0.8478
# Epoch 41/50
# 782/782 [==============================] - 31s 39ms/step - loss: 0.4228 - accuracy: 0.8592 - val_loss: 0.5494 - val_accuracy: 0.8281
# Epoch 42/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4178 - accuracy: 0.8589 - val_loss: 0.5429 - val_accuracy: 0.8262
# Epoch 43/50
# 782/782 [==============================] - 36s 46ms/step - loss: 0.4163 - accuracy: 0.8612 - val_loss: 0.4811 - val_accuracy: 0.8451
# Epoch 44/50
# 782/782 [==============================] - 35s 45ms/step - loss: 0.4064 - accuracy: 0.8648 - val_loss: 0.4414 - val_accuracy: 0.8597
# Epoch 45/50
# 782/782 [==============================] - 35s 45ms/step - loss: 0.4054 - accuracy: 0.8630 - val_loss: 0.4451 - val_accuracy: 0.8590
# Epoch 46/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3995 - accuracy: 0.8653 - val_loss: 0.4493 - val_accuracy: 0.8503
# Epoch 47/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4000 - accuracy: 0.8658 - val_loss: 0.4675 - val_accuracy: 0.8475
# Epoch 48/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.3943 - accuracy: 0.8683 - val_loss: 0.4897 - val_accuracy: 0.8482
# Epoch 49/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3986 - accuracy: 0.8666 - val_loss: 0.5446 - val_accuracy: 0.8224
# Epoch 50/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.3834 - accuracy: 0.8725 - val_loss: 0.4397 - val_accuracy: 0.8568

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy by AlexNet on CIFAR-10 Data")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss by AlexNet on CIFAR-10 Data')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
weights = AlexNet.get_weights()[0]
weights -= weights.min()
weights /= weights.max()

# Reshape the weights to have the same dimensions as the filters
weights = np.reshape(weights, (weights.shape[3], weights.shape[2], weights.shape[1]))

# Plot the filters
plt.figure(figsize=(10, 10))
for i in range(weights.shape[2]):
    plt.subplot(8, 8, i+1)
    plt.imshow(weights[:, :, i], cmap='gray')
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-9dfa8d1e7c66> in <cell line: 6>()
#       4
#       5 # Reshape the weights to have the same dimensions as the filters
# ----> 6 weights = np.reshape(weights, (weights.shape[3], weights.shape[2], weights.shape[1]))
#       7
#       8 # Plot the filters
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in reshape(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#     299
#     300
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 864 into shape (32,3,3)

# %%
y_predictions1 = AlexNet.predict(x_test)
y_predictions1.reshape(-1,)
y_predictions1= np.argmax(y_predictions1, axis=1)

confusion_matrix(y_test, y_predictions1)
# Out:
# 313/313 [==============================] - 1s 3ms/step
# array([[871,  16,  20,  11,   3,   5,   6,   9,  23,  36],
#        [  3, 958,   1,   1,   0,   3,   0,   0,   3,  31],
#        [ 42,   7, 782,  20,  37,  34,  44,  25,   3,   6],
#        [ 15,  11,  29, 657,  37, 140,  44,  37,   9,  21],
#        [  9,   1,  30,  24, 822,  15,  35,  58,   3,   3],
#        [  7,   6,  11,  75,  21, 811,  14,  43,   1,  11],
#        [  7,   3,  10,  19,   5,  10, 938,   2,   2,   4],
#        [  3,   2,  11,   9,  11,  24,   3, 928,   1,   8],
#        [ 50,  31,   6,   6,   1,   1,   2,   4, 871,  28],
#        [  3,  52,   2,   4,   0,   0,   0,   4,   5, 930]])

# %%
# confusion matrix and accuracy
plt.figure(figsize=(7, 6))
plt.title('Confusion matrix of AlexNet Model', fontsize=16)
plt.imshow(confusion_matrix(y_test, y_predictions1))
plt.xticks(np.arange(10), classes, rotation=45, fontsize=12)
plt.yticks(np.arange(10), classes, fontsize=12)
plt.colorbar()
plt.show()

# %%
from sklearn.metrics import accuracy_score
print("Test accuracy by AlexNet:", accuracy_score(y_test, y_predictions1))
# Out:
# Test accuracy by AlexNet: 0.8568

# %%
L = 8
W = 8
fig, axes = plt.subplots(L, W, figsize = (20,20))
axes = axes.ravel() # 

for i in np.arange(0, L * W):  
    axes[i].imshow(x_test[i])
    axes[i].set_title("Predicted = {}\n Actual  = {}".format(classes[y_predictions1[i]], classes[y_test[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
